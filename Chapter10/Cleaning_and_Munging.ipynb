# %%
from pprint import pprint
import csv
from collections import defaultdict

# %%
def parse_row(input_row, parsers):
    """given a list of parsers (some of which may be None)
    apply the appropriate one to each element of the input_row"""

    return [parser(value) if parser is not None else value
            for value, parser in zip(input_row, parsers)]

def parse_rows_with(reader, parsers):
    """wrap a reader to apply the parsers to each of its rows"""
    for row in reader:
        yield parse_row(row, parsers)

# %%
def try_or_none(f):
    """wraps f to return None if f raises an exception
    assumes f takes only one input"""
    def f_or_none(x):
        try: return f(x)
        except: return None
    return f_or_none

# %%
def parse_row(input_row, parsers):
    return [try_or_none(parser)(value) if parser is not None else value
            for value, parser in zip(input_row, parsers)]

# %%
import dateutil.parser
data = []

with open("comma_delimited_stock_prices.csv", "rb") as f:
    reader = csv.reader(f)
    for line in parse_rows_with(reader, [dateutil.parser.parse, None, float]):
        data.append(line)

pprint(data)
# Out:
# [[datetime.datetime(2014, 6, 20, 0, 0), 'AAPL', 90.91],
#  [datetime.datetime(2014, 6, 20, 0, 0), 'MSFT', 41.68],
#  [datetime.datetime(3014, 6, 20, 0, 0), 'FB', 64.5],
#  [datetime.datetime(2014, 6, 19, 0, 0), 'AAPL', 91.86],
#  [datetime.datetime(2014, 6, 19, 0, 0), 'MSFT', None],
#  [datetime.datetime(2014, 6, 19, 0, 0), 'FB', 64.34]]

# %%
for row in data:
    if any(x is None for x in row):
        print row
# Out:
# [datetime.datetime(2014, 6, 19, 0, 0), 'MSFT', None]

# %%
def try_parse_field(field_name, value, parser_dict):
    """try to parse value using the appropriate function from parser_dict"""
    parser = parser_dict.get(field_name)   # None if no such entry
    if parser is not None:
        return try_or_none(parser)(value)
    else:
        return value

def parse_dict(input_dict, parser_dict):
    return { field_name : try_parse_field(field_name, value, parser_dict)
             for field_name, value in input_dict.iteritems() }

# %%
data = []

with open("stocks.txt", "rb") as f:
        reader = csv.DictReader(f, delimiter="\t")
        data = [parse_dict(row, { 'date' : dateutil.parser.parse,
                                  'closing_price' : float }) 
                for row in reader]
        
pprint(data[:10])
# Out:
# [{'closing_price': 112.98,
#   'date': datetime.datetime(2015, 1, 23, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 112.4,
#   'date': datetime.datetime(2015, 1, 22, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 109.55,
#   'date': datetime.datetime(2015, 1, 21, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 108.72,
#   'date': datetime.datetime(2015, 1, 20, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 105.99,
#   'date': datetime.datetime(2015, 1, 16, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 106.82,
#   'date': datetime.datetime(2015, 1, 15, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 109.8,
#   'date': datetime.datetime(2015, 1, 14, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 110.22,
#   'date': datetime.datetime(2015, 1, 13, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 109.25,
#   'date': datetime.datetime(2015, 1, 12, 0, 0),
#   'symbol': 'AAPL'},
#  {'closing_price': 112.01,
#   'date': datetime.datetime(2015, 1, 9, 0, 0),
#   'symbol': 'AAPL'}]

# %%
max_aapl_price = max(row["closing_price"]
                     for row in data
                     if row["symbol"] == "AAPL")

max_aapl_price
# Out:
# 119.0

# %%
# group rows by symbol
by_symbol = defaultdict(list)
for row in data:
    by_symbol[row["symbol"]].append(row)

    # use a dict comprehension to find the max for each symbol
max_price_by_symbol = { symbol : max(row["closing_price"]
                                     for row in grouped_rows)
                        for symbol, grouped_rows in by_symbol.iteritems() }
max_price_by_symbol
# Out:
# {'AAPL': 119.0, 'FB': 81.45, 'MSFT': 49.3}

# %%
def picker(field_name):
    """returns a function that picks a field out of a dict"""
    return lambda row: row[field_name]

def pluck(field_name, rows):
    """turn a list of dicts into the list of field_name values"""
    return map(picker(field_name), rows)

# %%
def group_by(grouper, rows, value_transform=None):
    # key is output of grouper, value is list of rows
    grouped = defaultdict(list)
    for row in rows:
        grouped[grouper(row)].append(row)

    if value_transform is None:
        return grouped
    else:
        return { key : value_transform(rows)
                 for key, rows in grouped.iteritems() }

# %%
max_price_by_symbol_2 = group_by(picker("symbol"),
                               data,
                               lambda rows: max(pluck("closing_price", rows)))

max_price_by_symbol_2
# Out:
# {'AAPL': 119.0, 'FB': 81.45, 'MSFT': 49.3}

# %% [markdown]
# #### largest and smallest one-day percent changes

# %%
def percent_price_change(yesterday, today):
    return today["closing_price"] / yesterday["closing_price"] - 1

def day_over_day_changes(grouped_rows):
    # sort the rows by date
    ordered = sorted(grouped_rows, key=picker("date"))

    # zip with an offset to get pairs of consecutive days
    return [{ "symbol" : today["symbol"],
              "date" : today["date"],
              "change" : percent_price_change(yesterday, today) }
            for yesterday, today in zip(ordered, ordered[1:])]

# %%
# key is symbol, value is list of "change" dicts
changes_by_symbol = group_by(picker("symbol"), data, day_over_day_changes)
changes_by_symbol
# Out:
# {'AAPL': [{'change': -0.045454545454545525,
#    'date': datetime.datetime(1980, 12, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0714285714285714,
#    'date': datetime.datetime(1980, 12, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1980, 12, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.02499999999999991,
#    'date': datetime.datetime(1980, 12, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.07317073170731714,
#    'date': datetime.datetime(1980, 12, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.045454545454545414,
#    'date': datetime.datetime(1980, 12, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04347826086956519,
#    'date': datetime.datetime(1980, 12, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04166666666666674,
#    'date': datetime.datetime(1980, 12, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.10000000000000009,
#    'date': datetime.datetime(1980, 12, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0181818181818183,
#    'date': datetime.datetime(1980, 12, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0357142857142857,
#    'date': datetime.datetime(1980, 12, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.01851851851851849,
#    'date': datetime.datetime(1980, 12, 31, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 1, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.018867924528301883,
#    'date': datetime.datetime(1981, 1, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03846153846153855,
#    'date': datetime.datetime(1981, 1, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.040000000000000036,
#    'date': datetime.datetime(1981, 1, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02083333333333337,
#    'date': datetime.datetime(1981, 1, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.042553191489361764,
#    'date': datetime.datetime(1981, 1, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 1, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04081632653061229,
#    'date': datetime.datetime(1981, 1, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 1, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.02127659574468077,
#    'date': datetime.datetime(1981, 1, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 1, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0625,
#    'date': datetime.datetime(1981, 1, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03921568627450989,
#    'date': datetime.datetime(1981, 1, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.020408163265306145,
#    'date': datetime.datetime(1981, 1, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.020000000000000018,
#    'date': datetime.datetime(1981, 1, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 1, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.019607843137254943,
#    'date': datetime.datetime(1981, 1, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.020000000000000018,
#    'date': datetime.datetime(1981, 1, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.020408163265306145,
#    'date': datetime.datetime(1981, 1, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04166666666666663,
#    'date': datetime.datetime(1981, 1, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0434782608695653,
#    'date': datetime.datetime(1981, 1, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.06818181818181823,
#    'date': datetime.datetime(1981, 2, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04878048780487809,
#    'date': datetime.datetime(1981, 2, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.023255813953488413,
#    'date': datetime.datetime(1981, 2, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 2, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 2, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.045454545454545525,
#    'date': datetime.datetime(1981, 2, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 2, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.023809523809523836,
#    'date': datetime.datetime(1981, 2, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.024390243902438935,
#    'date': datetime.datetime(1981, 2, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.025000000000000022,
#    'date': datetime.datetime(1981, 2, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1981, 2, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1981, 2, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04761904761904756,
#    'date': datetime.datetime(1981, 2, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.07500000000000007,
#    'date': datetime.datetime(1981, 2, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.027027027027026973,
#    'date': datetime.datetime(1981, 2, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02631578947368418,
#    'date': datetime.datetime(1981, 2, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.05405405405405417,
#    'date': datetime.datetime(1981, 2, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1981, 2, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.02499999999999991,
#    'date': datetime.datetime(1981, 2, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 3, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 3, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.024390243902438935,
#    'date': datetime.datetime(1981, 3, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 3, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 3, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.10000000000000009,
#    'date': datetime.datetime(1981, 3, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02777777777777779,
#    'date': datetime.datetime(1981, 3, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.05714285714285705,
#    'date': datetime.datetime(1981, 3, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.06060606060606055,
#    'date': datetime.datetime(1981, 3, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02857142857142847,
#    'date': datetime.datetime(1981, 3, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0588235294117645,
#    'date': datetime.datetime(1981, 3, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0277777777777779,
#    'date': datetime.datetime(1981, 3, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.08108108108108114,
#    'date': datetime.datetime(1981, 3, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.025000000000000022,
#    'date': datetime.datetime(1981, 3, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1981, 3, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.02499999999999991,
#    'date': datetime.datetime(1981, 3, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 3, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.024390243902438935,
#    'date': datetime.datetime(1981, 3, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 3, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.050000000000000044,
#    'date': datetime.datetime(1981, 3, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 3, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 3, 31, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02631578947368418,
#    'date': datetime.datetime(1981, 4, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.10810810810810811,
#    'date': datetime.datetime(1981, 4, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 4, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.024390243902438935,
#    'date': datetime.datetime(1981, 4, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 4, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1981, 4, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 4, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.023809523809523725,
#    'date': datetime.datetime(1981, 4, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 4, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 4, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04651162790697683,
#    'date': datetime.datetime(1981, 4, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04878048780487798,
#    'date': datetime.datetime(1981, 4, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1981, 4, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1981, 4, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04761904761904767,
#    'date': datetime.datetime(1981, 4, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.022727272727272707,
#    'date': datetime.datetime(1981, 4, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 4, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.022222222222222254,
#    'date': datetime.datetime(1981, 4, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 4, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.022727272727272707,
#    'date': datetime.datetime(1981, 4, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.023255813953488413,
#    'date': datetime.datetime(1981, 4, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 5, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 5, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.022727272727272707,
#    'date': datetime.datetime(1981, 5, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.023255813953488413,
#    'date': datetime.datetime(1981, 5, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.023809523809523725,
#    'date': datetime.datetime(1981, 5, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 5, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.023255813953488413,
#    'date': datetime.datetime(1981, 5, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 5, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 5, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.023809523809523836,
#    'date': datetime.datetime(1981, 5, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.024390243902439046,
#    'date': datetime.datetime(1981, 5, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.023809523809523725,
#    'date': datetime.datetime(1981, 5, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.023255813953488413,
#    'date': datetime.datetime(1981, 5, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04761904761904767,
#    'date': datetime.datetime(1981, 5, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.045454545454545414,
#    'date': datetime.datetime(1981, 5, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04347826086956519,
#    'date': datetime.datetime(1981, 5, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 5, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0625,
#    'date': datetime.datetime(1981, 5, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 5, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 5, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 6, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03921568627450989,
#    'date': datetime.datetime(1981, 6, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 6, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.020408163265306145,
#    'date': datetime.datetime(1981, 6, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.020000000000000018,
#    'date': datetime.datetime(1981, 6, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04081632653061229,
#    'date': datetime.datetime(1981, 6, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.02127659574468077,
#    'date': datetime.datetime(1981, 6, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.02083333333333326,
#    'date': datetime.datetime(1981, 6, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04081632653061229,
#    'date': datetime.datetime(1981, 6, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.019607843137254943,
#    'date': datetime.datetime(1981, 6, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 6, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.020000000000000018,
#    'date': datetime.datetime(1981, 6, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.020408163265306145,
#    'date': datetime.datetime(1981, 6, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 6, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02083333333333337,
#    'date': datetime.datetime(1981, 6, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04255319148936165,
#    'date': datetime.datetime(1981, 6, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.022222222222222143,
#    'date': datetime.datetime(1981, 6, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.021739130434782594,
#    'date': datetime.datetime(1981, 6, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.022222222222222143,
#    'date': datetime.datetime(1981, 6, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.021739130434782594,
#    'date': datetime.datetime(1981, 6, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04444444444444451,
#    'date': datetime.datetime(1981, 6, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.06976744186046502,
#    'date': datetime.datetime(1981, 6, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 7, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 7, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.050000000000000044,
#    'date': datetime.datetime(1981, 7, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1981, 7, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1981, 7, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.07500000000000007,
#    'date': datetime.datetime(1981, 7, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.08108108108108103,
#    'date': datetime.datetime(1981, 7, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.02941176470588225,
#    'date': datetime.datetime(1981, 7, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.05714285714285716,
#    'date': datetime.datetime(1981, 7, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.027027027027026973,
#    'date': datetime.datetime(1981, 7, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1981, 7, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1981, 7, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.07500000000000007,
#    'date': datetime.datetime(1981, 7, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 7, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.05405405405405406,
#    'date': datetime.datetime(1981, 7, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.028571428571428692,
#    'date': datetime.datetime(1981, 7, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0277777777777779,
#    'date': datetime.datetime(1981, 7, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.05405405405405417,
#    'date': datetime.datetime(1981, 7, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.05128205128205132,
#    'date': datetime.datetime(1981, 7, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 7, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.027027027027026973,
#    'date': datetime.datetime(1981, 7, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1981, 7, 31, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02564102564102566,
#    'date': datetime.datetime(1981, 8, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1981, 8, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1981, 8, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.025000000000000022,
#    'date': datetime.datetime(1981, 8, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 8, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02564102564102566,
#    'date': datetime.datetime(1981, 8, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02631578947368418,
#    'date': datetime.datetime(1981, 8, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.027027027027027084,
#    'date': datetime.datetime(1981, 8, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02777777777777779,
#    'date': datetime.datetime(1981, 8, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02857142857142847,
#    'date': datetime.datetime(1981, 8, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02941176470588236,
#    'date': datetime.datetime(1981, 8, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 8, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 8, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.06060606060606066,
#    'date': datetime.datetime(1981, 8, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.06451612903225812,
#    'date': datetime.datetime(1981, 8, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1981, 8, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.033333333333333326,
#    'date': datetime.datetime(1981, 8, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1981, 8, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03333333333333344,
#    'date': datetime.datetime(1981, 8, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 8, 31, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.06451612903225823,
#    'date': datetime.datetime(1981, 9, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.030303030303030276,
#    'date': datetime.datetime(1981, 9, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.05882352941176472,
#    'date': datetime.datetime(1981, 9, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03125,
#    'date': datetime.datetime(1981, 9, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.032258064516129115,
#    'date': datetime.datetime(1981, 9, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 9, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03333333333333344,
#    'date': datetime.datetime(1981, 9, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.032258064516129115,
#    'date': datetime.datetime(1981, 9, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.033333333333333326,
#    'date': datetime.datetime(1981, 9, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 9, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1981, 9, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0357142857142857,
#    'date': datetime.datetime(1981, 9, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 9, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03703703703703698,
#    'date': datetime.datetime(1981, 9, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.07142857142857151,
#    'date': datetime.datetime(1981, 9, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03846153846153855,
#    'date': datetime.datetime(1981, 9, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 9, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.12,
#    'date': datetime.datetime(1981, 9, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 9, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.045454545454545414,
#    'date': datetime.datetime(1981, 9, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04347826086956519,
#    'date': datetime.datetime(1981, 9, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 10, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04166666666666674,
#    'date': datetime.datetime(1981, 10, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.040000000000000036,
#    'date': datetime.datetime(1981, 10, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 10, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0769230769230771,
#    'date': datetime.datetime(1981, 10, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1981, 10, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 10, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1981, 10, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 10, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.06666666666666654,
#    'date': datetime.datetime(1981, 10, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1981, 10, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1981, 10, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1981, 10, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1981, 10, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 10, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 10, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.033333333333333326,
#    'date': datetime.datetime(1981, 10, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 10, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1981, 10, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03333333333333344,
#    'date': datetime.datetime(1981, 10, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.032258064516129115,
#    'date': datetime.datetime(1981, 10, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03333333333333344,
#    'date': datetime.datetime(1981, 10, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.032258064516129115,
#    'date': datetime.datetime(1981, 11, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.06666666666666654,
#    'date': datetime.datetime(1981, 11, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1981, 11, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1981, 11, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.06666666666666654,
#    'date': datetime.datetime(1981, 11, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1981, 11, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1981, 11, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1981, 11, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 11, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1981, 12, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.033333333333333326,
#    'date': datetime.datetime(1981, 12, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1981, 12, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1981, 12, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1981, 12, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.10000000000000009,
#    'date': datetime.datetime(1981, 12, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.06060606060606055,
#    'date': datetime.datetime(1981, 12, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02857142857142847,
#    'date': datetime.datetime(1981, 12, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.05882352941176472,
#    'date': datetime.datetime(1981, 12, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03125,
#    'date': datetime.datetime(1981, 12, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.030303030303030276,
#    'date': datetime.datetime(1981, 12, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1981, 12, 31, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.05882352941176472,
#    'date': datetime.datetime(1982, 1, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.09375000000000011,
#    'date': datetime.datetime(1982, 1, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.06896551724137945,
#    'date': datetime.datetime(1982, 1, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.06451612903225812,
#    'date': datetime.datetime(1982, 1, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1982, 1, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1982, 1, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.06896551724137945,
#    'date': datetime.datetime(1982, 1, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.032258064516129004,
#    'date': datetime.datetime(1982, 1, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03125,
#    'date': datetime.datetime(1982, 1, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.032258064516129115,
#    'date': datetime.datetime(1982, 1, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03333333333333344,
#    'date': datetime.datetime(1982, 1, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 1, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.032258064516129115,
#    'date': datetime.datetime(1982, 2, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.033333333333333326,
#    'date': datetime.datetime(1982, 2, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1982, 2, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1982, 2, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1982, 2, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 2, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.07142857142857151,
#    'date': datetime.datetime(1982, 3, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03846153846153855,
#    'date': datetime.datetime(1982, 3, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.040000000000000036,
#    'date': datetime.datetime(1982, 3, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04166666666666663,
#    'date': datetime.datetime(1982, 3, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0434782608695653,
#    'date': datetime.datetime(1982, 3, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.09090909090909083,
#    'date': datetime.datetime(1982, 3, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.08333333333333348,
#    'date': datetime.datetime(1982, 3, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0769230769230771,
#    'date': datetime.datetime(1982, 3, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0357142857142857,
#    'date': datetime.datetime(1982, 3, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03703703703703709,
#    'date': datetime.datetime(1982, 3, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03846153846153855,
#    'date': datetime.datetime(1982, 3, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.040000000000000036,
#    'date': datetime.datetime(1982, 3, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 3, 31, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03846153846153855,
#    'date': datetime.datetime(1982, 4, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.07407407407407418,
#    'date': datetime.datetime(1982, 4, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.040000000000000036,
#    'date': datetime.datetime(1982, 4, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03846153846153855,
#    'date': datetime.datetime(1982, 4, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.040000000000000036,
#    'date': datetime.datetime(1982, 4, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04166666666666663,
#    'date': datetime.datetime(1982, 4, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 4, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04347826086956519,
#    'date': datetime.datetime(1982, 5, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04166666666666674,
#    'date': datetime.datetime(1982, 5, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.040000000000000036,
#    'date': datetime.datetime(1982, 5, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04166666666666663,
#    'date': datetime.datetime(1982, 5, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04347826086956519,
#    'date': datetime.datetime(1982, 5, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04166666666666663,
#    'date': datetime.datetime(1982, 5, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0434782608695653,
#    'date': datetime.datetime(1982, 5, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 5, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.045454545454545525,
#    'date': datetime.datetime(1982, 6, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04761904761904767,
#    'date': datetime.datetime(1982, 6, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.045454545454545525,
#    'date': datetime.datetime(1982, 6, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04761904761904756,
#    'date': datetime.datetime(1982, 6, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1982, 6, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04761904761904756,
#    'date': datetime.datetime(1982, 6, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1982, 6, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04761904761904756,
#    'date': datetime.datetime(1982, 6, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 6, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.050000000000000044,
#    'date': datetime.datetime(1982, 7, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.052631578947368474,
#    'date': datetime.datetime(1982, 7, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.05555555555555547,
#    'date': datetime.datetime(1982, 7, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0588235294117645,
#    'date': datetime.datetime(1982, 7, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.05555555555555558,
#    'date': datetime.datetime(1982, 7, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.05263157894736836,
#    'date': datetime.datetime(1982, 7, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1982, 7, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04761904761904767,
#    'date': datetime.datetime(1982, 7, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.045454545454545525,
#    'date': datetime.datetime(1982, 7, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04761904761904756,
#    'date': datetime.datetime(1982, 7, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1982, 7, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 7, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04761904761904756,
#    'date': datetime.datetime(1982, 8, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.050000000000000044,
#    'date': datetime.datetime(1982, 8, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.05263157894736836,
#    'date': datetime.datetime(1982, 8, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1982, 8, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04761904761904767,
#    'date': datetime.datetime(1982, 8, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.045454545454545414,
#    'date': datetime.datetime(1982, 8, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04347826086956519,
#    'date': datetime.datetime(1982, 8, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04166666666666674,
#    'date': datetime.datetime(1982, 8, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.08000000000000007,
#    'date': datetime.datetime(1982, 8, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.03703703703703709,
#    'date': datetime.datetime(1982, 8, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 8, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0769230769230771,
#    'date': datetime.datetime(1982, 8, 31, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0357142857142857,
#    'date': datetime.datetime(1982, 9, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03703703703703698,
#    'date': datetime.datetime(1982, 9, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0357142857142857,
#    'date': datetime.datetime(1982, 9, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03703703703703698,
#    'date': datetime.datetime(1982, 9, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0357142857142857,
#    'date': datetime.datetime(1982, 9, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03703703703703698,
#    'date': datetime.datetime(1982, 9, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1982, 9, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1982, 9, 16, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0357142857142857,
#    'date': datetime.datetime(1982, 9, 17, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03703703703703698,
#    'date': datetime.datetime(1982, 9, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1982, 9, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 23, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1982, 9, 24, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 9, 30, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1982, 10, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.06896551724137945,
#    'date': datetime.datetime(1982, 10, 6, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.09677419354838723,
#    'date': datetime.datetime(1982, 10, 7, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0588235294117645,
#    'date': datetime.datetime(1982, 10, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0277777777777779,
#    'date': datetime.datetime(1982, 10, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.027027027027027084,
#    'date': datetime.datetime(1982, 10, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 13, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 14, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 18, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0277777777777779,
#    'date': datetime.datetime(1982, 10, 19, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.05405405405405417,
#    'date': datetime.datetime(1982, 10, 20, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1982, 10, 21, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 22, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.050000000000000044,
#    'date': datetime.datetime(1982, 10, 25, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 26, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1982, 10, 27, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 28, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0,
#    'date': datetime.datetime(1982, 10, 29, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0512820512820511,
#    'date': datetime.datetime(1982, 11, 1, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.07317073170731714,
#    'date': datetime.datetime(1982, 11, 2, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.06818181818181812,
#    'date': datetime.datetime(1982, 11, 3, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.02127659574468077,
#    'date': datetime.datetime(1982, 11, 4, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.02083333333333337,
#    'date': datetime.datetime(1982, 11, 5, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.04255319148936165,
#    'date': datetime.datetime(1982, 11, 8, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.022222222222222143,
#    'date': datetime.datetime(1982, 11, 9, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.04347826086956519,
#    'date': datetime.datetime(1982, 11, 10, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': 0.0625,
#    'date': datetime.datetime(1982, 11, 11, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.019607843137254943,
#    'date': datetime.datetime(1982, 11, 12, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.020000000000000018,
#    'date': datetime.datetime(1982, 11, 15, 0, 0),
#    'symbol': 'AAPL'},
#   {'change': -0.061224489795918324,
# ...
#    'symbol': 'MSFT'},
#   {'change': 0.03846153846153855,
#    'date': datetime.datetime(1989, 7, 7, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 10, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 11, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 12, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.03703703703703709,
#    'date': datetime.datetime(1989, 7, 13, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 14, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03846153846153855,
#    'date': datetime.datetime(1989, 7, 17, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 18, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 19, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 20, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 21, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 24, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.03703703703703709,
#    'date': datetime.datetime(1989, 7, 25, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 26, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03846153846153855,
#    'date': datetime.datetime(1989, 7, 27, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 28, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 7, 31, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 1, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 2, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 3, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03703703703703698,
#    'date': datetime.datetime(1989, 8, 4, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1989, 8, 7, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 8, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 9, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 10, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 11, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1989, 8, 14, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1989, 8, 15, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1989, 8, 16, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 17, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1989, 8, 18, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.0344827586206895,
#    'date': datetime.datetime(1989, 8, 21, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03571428571428559,
#    'date': datetime.datetime(1989, 8, 22, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 23, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 24, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 25, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 28, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 29, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 30, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 8, 31, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1989, 9, 1, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 5, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.033333333333333326,
#    'date': datetime.datetime(1989, 9, 6, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 7, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 8, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.034482758620689724,
#    'date': datetime.datetime(1989, 9, 11, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 12, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03333333333333344,
#    'date': datetime.datetime(1989, 9, 13, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.032258064516129004,
#    'date': datetime.datetime(1989, 9, 14, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.03125,
#    'date': datetime.datetime(1989, 9, 15, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.032258064516129004,
#    'date': datetime.datetime(1989, 9, 18, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.03125,
#    'date': datetime.datetime(1989, 9, 19, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.032258064516129004,
#    'date': datetime.datetime(1989, 9, 20, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.03125,
#    'date': datetime.datetime(1989, 9, 21, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 22, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 25, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 26, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 27, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.030303030303030276,
#    'date': datetime.datetime(1989, 9, 28, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 9, 29, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.02941176470588225,
#    'date': datetime.datetime(1989, 10, 2, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.02857142857142847,
#    'date': datetime.datetime(1989, 10, 3, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.11764705882352944,
#    'date': datetime.datetime(1989, 10, 4, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1989, 10, 5, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1989, 10, 6, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.02499999999999991,
#    'date': datetime.datetime(1989, 10, 9, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.024390243902438935,
#    'date': datetime.datetime(1989, 10, 10, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 10, 11, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.025000000000000022,
#    'date': datetime.datetime(1989, 10, 12, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.05128205128205132,
#    'date': datetime.datetime(1989, 10, 13, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.027027027027026973,
#    'date': datetime.datetime(1989, 10, 16, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1989, 10, 17, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1989, 10, 18, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.04999999999999982,
#    'date': datetime.datetime(1989, 10, 19, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 10, 20, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.023809523809523836,
#    'date': datetime.datetime(1989, 10, 23, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.024390243902438935,
#    'date': datetime.datetime(1989, 10, 24, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 10, 25, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.025000000000000022,
#    'date': datetime.datetime(1989, 10, 26, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.02564102564102566,
#    'date': datetime.datetime(1989, 10, 27, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.05263157894736836,
#    'date': datetime.datetime(1989, 10, 30, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.02499999999999991,
#    'date': datetime.datetime(1989, 10, 31, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 1, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.07317073170731703,
#    'date': datetime.datetime(1989, 11, 2, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1989, 11, 3, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.02564102564102566,
#    'date': datetime.datetime(1989, 11, 6, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.05263157894736836,
#    'date': datetime.datetime(1989, 11, 7, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.02499999999999991,
#    'date': datetime.datetime(1989, 11, 8, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.024390243902439046,
#    'date': datetime.datetime(1989, 11, 9, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 10, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.04761904761904767,
#    'date': datetime.datetime(1989, 11, 13, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.022727272727272707,
#    'date': datetime.datetime(1989, 11, 14, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.023255813953488413,
#    'date': datetime.datetime(1989, 11, 15, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 16, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.022727272727272707,
#    'date': datetime.datetime(1989, 11, 17, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 20, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.023255813953488413,
#    'date': datetime.datetime(1989, 11, 21, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 22, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 24, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.022727272727272707,
#    'date': datetime.datetime(1989, 11, 27, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 28, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 29, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 11, 30, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.023255813953488413,
#    'date': datetime.datetime(1989, 12, 1, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.023809523809523725,
#    'date': datetime.datetime(1989, 12, 4, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 12, 5, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.023255813953488413,
#    'date': datetime.datetime(1989, 12, 6, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.023809523809523725,
#    'date': datetime.datetime(1989, 12, 7, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.023255813953488413,
#    'date': datetime.datetime(1989, 12, 8, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.023809523809523836,
#    'date': datetime.datetime(1989, 12, 11, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 12, 12, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.024390243902438935,
#    'date': datetime.datetime(1989, 12, 13, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.025000000000000022,
#    'date': datetime.datetime(1989, 12, 14, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.02564102564102566,
#    'date': datetime.datetime(1989, 12, 15, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.026315789473684292,
#    'date': datetime.datetime(1989, 12, 18, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.025641025641025772,
#    'date': datetime.datetime(1989, 12, 19, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.02499999999999991,
#    'date': datetime.datetime(1989, 12, 20, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.024390243902439046,
#    'date': datetime.datetime(1989, 12, 21, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.023809523809523725,
#    'date': datetime.datetime(1989, 12, 22, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 12, 26, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1989, 12, 27, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.023255813953488413,
#    'date': datetime.datetime(1989, 12, 28, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.023809523809523725,
#    'date': datetime.datetime(1989, 12, 29, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.023255813953488413,
#    'date': datetime.datetime(1990, 1, 2, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 3, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.045454545454545414,
#    'date': datetime.datetime(1990, 1, 4, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.021739130434782594,
#    'date': datetime.datetime(1990, 1, 5, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 8, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 9, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.022222222222222254,
#    'date': datetime.datetime(1990, 1, 10, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.022727272727272707,
#    'date': datetime.datetime(1990, 1, 11, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 12, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 15, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.023255813953488413,
#    'date': datetime.datetime(1990, 1, 16, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 17, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.06818181818181812,
#    'date': datetime.datetime(1990, 1, 18, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 19, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.04255319148936165,
#    'date': datetime.datetime(1990, 1, 22, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 23, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 24, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 25, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 1, 26, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.022222222222222143,
#    'date': datetime.datetime(1990, 1, 29, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.021739130434782594,
#    'date': datetime.datetime(1990, 1, 30, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.022222222222222143,
#    'date': datetime.datetime(1990, 1, 31, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.021739130434782483,
#    'date': datetime.datetime(1990, 2, 1, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 2, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 5, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 6, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.02127659574468077,
#    'date': datetime.datetime(1990, 2, 7, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.021739130434782483,
#    'date': datetime.datetime(1990, 2, 8, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 9, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 12, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 13, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 14, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.02127659574468077,
#    'date': datetime.datetime(1990, 2, 15, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.02083333333333326,
#    'date': datetime.datetime(1990, 2, 16, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.020408163265306145,
#    'date': datetime.datetime(1990, 2, 20, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': -0.040000000000000036,
#    'date': datetime.datetime(1990, 2, 21, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 22, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.02083333333333326,
#    'date': datetime.datetime(1990, 2, 23, 0, 0),
#    'symbol': 'MSFT'},
#   {'change': 0.0,
#    'date': datetime.datetime(1990, 2, 26, 0, 0),
#    'symbol': 'MSFT'},
#   ...]}

# %%
from random import sample
# collect all "change" dicts into one big list
all_changes = [change
               for changes in changes_by_symbol.values()
               for change in changes]
sample(all_changes, 5)
# Out:
# [{'change': 0.058495821727019504,
#   'date': datetime.datetime(2000, 1, 25, 0, 0),
#   'symbol': 'AAPL'},
#  {'change': -0.005392799883399024,
#   'date': datetime.datetime(2013, 1, 18, 0, 0),
#   'symbol': 'AAPL'},
#  {'change': -0.022900763358778664,
#   'date': datetime.datetime(1995, 4, 13, 0, 0),
#   'symbol': 'AAPL'},
#  {'change': 0.00512820512820511,
#   'date': datetime.datetime(1992, 12, 28, 0, 0),
#   'symbol': 'MSFT'},
#  {'change': -0.005638340716874635,
#   'date': datetime.datetime(2008, 5, 2, 0, 0),
#   'symbol': 'MSFT'}]

# %%
max(all_changes, key=picker("change"))
# Out:
# {'change': 0.3283582089552237,
#  'date': datetime.datetime(1997, 8, 6, 0, 0),
#  'symbol': 'AAPL'}

# %%
min(all_changes, key=picker("change"))
# Out:
# {'change': -0.5193370165745856,
#  'date': datetime.datetime(2000, 9, 29, 0, 0),
#  'symbol': 'AAPL'}

# %%
def combine_pct_changes(pct_change1, pct_change2):
    return (1 + pct_change1) * (1 + pct_change2) - 1

def overall_change(changes):
    return reduce(combine_pct_changes, pluck("change", changes))

overall_change_by_month = group_by(lambda row: row['date'].month,
                                   all_changes,
                                   overall_change)

overall_change_by_month
# Out:
# {1: 19.972214514609067,
#  2: 0.11858483359214822,
#  3: 2.8188500486033203,
#  4: 6.934196784984757,
#  5: 1.2555660890321572,
#  6: -0.5977889232201739,
#  7: -0.17183091713561516,
#  8: 6.220055959879486,
#  9: -0.7411625436428328,
#  10: 21.55254125167998,
#  11: 3.758572336791728,
#  12: 2.2895332950255884}
